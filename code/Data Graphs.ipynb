# %%
import pandas as  pd
import missingno as msno
# %matplotlib inline

# %%
df=pd.read_csv('../data/data.csv')

# %%
msno.matrix(df.sample(250))

# %%
msno.heatmap(df)

# %%
msno.dendrogram(df)

# %%
msno.bar(df.sample(100))

# %%
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
bp=df.boxplot()

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# ID           147.5000
# Response       1.0000
# Group          1.0000
# X1           170.0000
# X2           528.5000
# X3           840.0000
# X4            81.7675
# X5            52.9125
# X6             1.2000
# X7          1151.1500
# Y1             1.0000
# Y2             1.0000
# Y3             1.0000
# Y4             1.0000
# Y5             1.0000
# Y6             1.0000
# Y7             1.0000
# dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
# Out:
# (array([211, 215, 218, 252], dtype=int64), array([6, 6, 6, 6], dtype=int64))
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in greater

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# (0, 17)
